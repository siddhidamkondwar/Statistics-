# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhidamkondwar/Statistics-/blob/main/stact_lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name = 'ERPData')

# %%
import pandas as pd

# %%
import numpy as np

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
x1 = df.MaterialID
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13059/1871196276.py in <cell line: 0>()
# ----> 1 x1 = df.MaterialID
#
# NameError: name 'df' is not defined

# %%
np.unique(x1)    #Q.How many unique material ids are there
# Out:
# array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#       dtype=object)

# %%
len(np.unique(x1))   #lenght of unique material id
# Out:
# 6

# %%
np.unique(x1, return_counts=True)
# Out:
# (array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#        dtype=object),
#  array([11,  8,  5,  5,  6, 15]))

# %%
x1.value_counts()
# Out:
# MaterialID
# TMI-43T    15
# AXCP-78    11
# DDBN-89     8
# SDRT-67     6
# GCVB-79     5
# LXCV-21     5
# Name: count, dtype: int64

# %%
df1 = x1.value_counts().reset_index()

# %%
df1
# Out:
#   MaterialID  count
# 0    TMI-43T     15
# 1    AXCP-78     11
# 2    DDBN-89      8
# 3    SDRT-67      6
# 4    GCVB-79      5
# 5    LXCV-21      5

# %% [markdown]
# Proportional

# %%
df1['prop'] = df1['count']/sum(df1['count'])

# %%
df1
# Out:
#   MaterialID  count  prop
# 0    TMI-43T     15  0.30
# 1    AXCP-78     11  0.22
# 2    DDBN-89      8  0.16
# 3    SDRT-67      6  0.12
# 4    GCVB-79      5  0.10
# 5    LXCV-21      5  0.10

# %%
df1['pct'] = df1['prop']*100

# %%
df1
# Out:
#   MaterialID  count  prop   pct
# 0    TMI-43T     15  0.30  30.0
# 1    AXCP-78     11  0.22  22.0
# 2    DDBN-89      8  0.16  16.0
# 3    SDRT-67      6  0.12  12.0
# 4    GCVB-79      5  0.10  10.0
# 5    LXCV-21      5  0.10  10.0

# %%
x2 = np.array([4,7,5,2,3,8])

# %%
np.cumsum(x2)      #cumilative sum
# Out:
# array([ 4, 11, 16, 18, 21, 29])

# %%
df1['CumPct'] = np.cumsum(df1['pct'])

# %%
df1
# Out:
#   MaterialID  count  prop   pct  CumPct
# 0    TMI-43T     15  0.30  30.0    30.0
# 1    AXCP-78     11  0.22  22.0    52.0
# 2    DDBN-89      8  0.16  16.0    68.0
# 3    SDRT-67      6  0.12  12.0    80.0
# 4    GCVB-79      5  0.10  10.0    90.0
# 5    LXCV-21      5  0.10  10.0   100.0

# %%
df2 = df1.sort_values('pct',ascending=False).head(3)

# %%
df1.iloc[1]
# Out:
# MaterialID    AXCP-78
# count              11
# prop             0.22
# pct              22.0
# CumPct           52.0
# Name: 1, dtype: object

# %%
# CENTRAL TENDANCY - MEAN ,MEDIAN , MODE
#dispersion or variation or spread -  range , inter quartile range , variance and std variance
# shaape - skewness and kurtosis

# %%
x =np.array([3,4,5,6])
f=np.array([20,18,9,12])

# %%
mean = sum(x*f)/sum(f)

# %%
mean
# Out:
# np.float64(4.220338983050848)

# %%
import copy #shallow copy

# %%
a=[1,2,3]

# %%
b=a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
b.append(4)

# %%
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2, 3, 4]
