# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhidamkondwar/Statistics-/blob/main/stat_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name = 'faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
x1 = df.eruptions

# %%
len(x1)
# Out:
# 272

# %%
sum(x1)/len(x1)
# Out:
# 3.487783088235294

# %%
np.mean(x1)
# Out:
# np.float64(3.4877830882352936)

# %%
np.median(x1)
# Out:
# np.float64(4.0)

# %%
import scipy

# %%
from scipy import stats

# %%
stats.mode(x1)
# Out:
# ModeResult(mode=np.float64(1.867), count=np.int64(8))

# %%
len(np.where(x1==1.867)[0])
# Out:
# 8

# %%
from collections import Counter

# %%
Counter(x1).most_common()                    #
# Out:
# [(1.867, 8),
#  (4.5, 8),
#  (1.833, 7),
#  (4.7, 6),
#  (1.75, 6),
#  (4.8, 6),
#  (4.0, 6),
#  (4.533, 5),
#  (4.083, 5),
#  (3.833, 5),
#  (4.333, 5),
#  (3.6, 4),
#  (1.8, 4),
#  (4.35, 4),
#  (4.25, 4),
#  (1.883, 4),
#  (2.0, 4),
#  (4.167, 4),
#  (4.417, 4),
#  (4.6, 4),
#  (4.15, 4),
#  (4.583, 4),
#  (3.917, 3),
#  (1.967, 3),
#  (2.017, 3),
#  (4.567, 3),
#  (2.1, 3),
#  (4.633, 3),
#  (1.817, 3),
#  (1.983, 3),
#  (4.933, 3),
#  (2.2, 3),
#  (4.367, 3),
#  (4.233, 3),
#  (4.45, 3),
#  (3.333, 2),
#  (2.167, 2),
#  (3.85, 2),
#  (4.433, 2),
#  (4.3, 2),
#  (4.467, 2),
#  (4.033, 2),
#  (4.833, 2),
#  (2.233, 2),
#  (4.133, 2),
#  (4.1, 2),
#  (4.067, 2),
#  (3.95, 2),
#  (4.817, 2),
#  (4.667, 2),
#  (4.9, 2),
#  (1.783, 2),
#  (3.767, 2),
#  (1.917, 2),
#  (2.033, 2),
#  (2.4, 2),
#  (3.567, 2),
#  (3.5, 2),
#  (1.933, 2),
#  (2.083, 2),
#  (2.417, 2),
#  (2.25, 2),
#  (4.267, 2),
#  (4.117, 2),
#  (1.85, 2),
#  (4.283, 2),
#  (2.283, 1),
#  (2.883, 1),
#  (1.95, 1),
# ...

# %%
max(x1) - min(x1)
# Out:
# 3.4999999999999996

# %%
np.ptp(x1)
# Out:
# np.float64(3.4999999999999996)

# %%
IQR = np.percentile(x1,75) - np.percentile(x1,25)

# %%
IQR
# Out:
# np.float64(2.2915)

# %%
#population varance
#pop std dev

#sample variance
#sample std dev

# %%
x2 = [4,3,6,5,7,9,4,8,7,3]

# %%
np.var(x2)
# Out:
# np.float64(4.04)

# %%
np.std(x2)
# Out:
# np.float64(2.009975124224178)

# %%
np.var(x2, ddof=1)
# Out:
# np.float64(4.488888888888889)

# %%
np.std(x2, ddof=1)   #ddof=degrees of freedom
# Out:
# np.float64(2.1186998109427604)

# %%
from scipy.stats import binom

# %% [markdown]
# Chances of rain on the any day

# %%
binom.pmf(
    10,15,0.7
)
# Out:
# np.float64(0.20613038097752098)

# %%
binom.cdf(10,15,0.7)
# Out:
# np.float64(0.4845089407731571)

# %%
#case3: no includesd in case 3 is  10 11 12 13 14 15

# %%
1-binom.cdf(10,15,0.7)
# Out:
# np.float64(0.5154910592268429)

# %%
#possion distrubution
#avg no of occurances is 15 what is the probabbilty of
# a. exactly 12 incidents taking place today

# %%
from scipy.stats import poisson

# %%
poisson.pmf(12,15)
# Out:
# np.float64(0.08285923436864541)

# %%
#b. upto 12 incidents take place

# %%
poisson.cdf(12,15)
# Out:
# np.float64(0.2676110333925769)

# %%
#c. minimum 12 incidents take place

# %%
1-poisson.cdf(11,15)
# Out:
# np.float64(0.8152482009760685)

# %%
poisson.sf(11,15)
# Out:
# np.float64(0.8152482009760685)

# %%
# normal distribution

# %%
from scipy.stats import norm, t

# %%
norm.cdf(14,16,2.3)    #14=14hrs 16=mean 2.3= sd
# Out:
# np.float64(0.19226902649831168)

# %%
1 - norm.cdf(14,16,2.3)
# Out:
# np.float64(0.8077309735016883)

# %%
norm.sf(14,16,2.3)
# Out:
# np.float64(0.8077309735016883)

# %%
norm.cdf(13,16,2.3)+norm.cdf(17,16,2.3)/2
# Out:
# np.float64(0.4301274503783719)

# %%
norm.cdf(17,16,2.3)-norm.cdf(13,16,2.3)
# Out:
# np.float64(0.5720823773874264)

# %%
z = (14-16)/2.3

# %%
norm.cdf(z)   #another way of finding norm.cdf fun where we calculate z (value-mean)/sd
# Out:
# np.float64(0.19226902649831168)
