# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhidamkondwar/Statistics-/blob/main/stat_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from numpy import linalg
import scipy
from scipy import stats
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm, t
from scipy.stats import expon
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel

# %%
binom.pmf(50,80,0.7)
# Out:
# np.float64(0.032849776371998936)

# %%
1-binom.cdf(49,80,0.7)    #even pro is low :possion
# Out:
# np.float64(0.9412518864088271)

# %%
norm.cdf(43,45,2.8)
# Out:
# np.float64(0.2375252620269765)

# %%
z = (43-45)/2.8

# %%
z
# Out:
# -0.7142857142857143

# %%
norm.cdf(z,0,1)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(z)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(1.73)
# Out:
# np.float64(0.9581848623864051)

# %%
z = (14-15.3)/1.8

# %%
t.cdf(z,14)
# Out:
# np.float64(0.2410240907076217)

# %%
from scipy.stats import expon

# %%
expon.cdf(100,scale=43.8)
# Out:
# np.float64(0.898032895521957)

# %%
0.3*60
# Out:
# 18.0

# %%
expon.cdf(1,scale=0.3)
# Out:
# np.float64(0.9643260066527476)

# %%
#on an avg sir will come 30 times in a 45 days course for 8hra  what is pro that he will come todah

# %%
expon.cdf(8,scale=12)
# Out:
# np.float64(0.486582880967408)

# %%
45*8/30
# Out:
# 12.0

# %%
df = pd.read_excel('/content/data1.xlsx')

# %%
df.head()
# Out:
#   Category
# 0        C
# 1        D
# 2        C
# 3        A
# 4        B

# %%
df.Category.isnull().sum()              #sum of all null values
# Out:
# np.int64(80)

# %%
np.where(df.Category.isnull())                  #indieces of all missing values
# Out:
# (array([  9,  11,  15,  32,  35,  38,  47,  48,  58,  59,  62,  64,  80,
#          81,  82,  84,  95,  98, 122, 123, 140, 156, 161, 163, 164, 165,
#         166, 167, 170, 174, 176, 177, 188, 192, 193, 212, 217, 223, 227,
#         231, 237, 238, 246, 248, 250, 254, 257, 260, 267, 268, 269, 278,
#         281, 287, 303, 328, 329, 333, 342, 345, 349, 357, 382, 384, 387,
#         404, 406, 441, 445, 447, 451, 456, 459, 464, 471, 476, 477, 490,
#         492, 494]),)

# %%
80/df.shape[0]
# Out:
# 0.16

# %%
from collections import Counter

# %%
Counter(df.Category).most_common()              #indices of most common category
# Out:
# [('B', 113), ('A', 112), ('C', 101), ('D', 94), (nan, 80)]

# %%
#df.Category.fillna('B',inplace=True)

# %%
df.Category.value_counts()
# Out:
# Category
# B    113
# A    112
# C    101
# D     94
# Name: count, dtype: int64

# %%
props=pd.DataFrame(df.Category.value_counts())

# %%
props['proportion']=props['count']/sum(props['count'])

# %%
props
# Out:
#           count  proportion
# Category
# B           113    0.269048
# A           112    0.266667
# C           101    0.240476
# D            94    0.223810

# %%
random_values=np.random.choice(['A','B','C','D'],size=80,p=props.proportion)

# %%
props
# Out:
#           count  proportion
# Category
# B           113    0.269048
# A           112    0.266667
# C           101    0.240476
# D            94    0.223810

# %%
df.head()
# Out:
#   Category
# 0        C
# 1        D
# 2        C
# 3        A
# 4        B

# %%
ind = np.where(df.Category.isnull())

# %%
df.loc[ind[0],'Category'] = random_values

# %%
df.Category.isnull().sum()
# Out:
# np.int64(0)

# %%
#df.Quantity.fillna(df.Quantity.meadian())

# %%
df1 = pd.read_excel('data2.xlsx')

# %%
df1.head()
# Out:
#   Category  Continuous_Value
# 0        C      -4008.098297
# 1        D      -3887.888132
# 2      NaN      -3712.188312
# 3        C      -3416.823821
# 4        D      -5845.073897

# %%
df1.Continuous_Value.isnull().sum()
# Out:
# np.int64(120)

# %%
df1.Continuous_Value.fillna(df1.Continuous_Value.median(),inplace=True)
# Out:
# /tmp/ipykernel_3294/127419712.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1.Continuous_Value.fillna(df1.Continuous_Value.median(),inplace=True)

# %%
df1.Continuous_Value.isnull().sum()
# Out:
# np.int64(0)

# %%
df1.head()
# Out:
#   Category  Continuous_Value
# 0        C      -4008.098297
# 1        D      -3887.888132
# 2      NaN      -3712.188312
# 3        C      -3416.823821
# 4        D      -5845.073897

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          850 non-null    object
#  1   Continuous_Value  1000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 15.8+ KB

# %%
#Q1=4411.78
#median=5030.24
#Q3 =5564.63
#IQR = 1152.84
#Wiskers =2697.30 ,7290.88
#n = 1000

# %%
plt.boxplot
# Out:
# <function matplotlib.pyplot.boxplot(x: 'ArrayLike | Sequence[ArrayLike]', *, notch: 'bool | None' = None, sym: 'str | None' = None, vert: 'bool | None' = None, orientation: "Literal['vertical', 'horizontal']" = 'vertical', whis: 'float | tuple[float, float] | None' = None, positions: 'ArrayLike | None' = None, widths: 'float | ArrayLike | None' = None, patch_artist: 'bool | None' = None, bootstrap: 'int | None' = None, usermedians: 'ArrayLike | None' = None, conf_intervals: 'ArrayLike | None' = None, meanline: 'bool | None' = None, showmeans: 'bool | None' = None, showcaps: 'bool | None' = None, showbox: 'bool | None' = None, showfliers: 'bool | None' = None, boxprops: 'dict[str, Any] | None' = None, tick_labels: 'Sequence[str] | None' = None, flierprops: 'dict[str, Any] | None' = None, medianprops: 'dict[str, Any] | None' = None, meanprops: 'dict[str, Any] | None' = None, capprops: 'dict[str, Any] | None' = None, whiskerprops: 'dict[str, Any] | None' = None, manage_ticks: 'bool' = T
# ...

# %%
states = ['KA','MH','AP','MP','UP']
counts = [40,35,50,20,15]

# %%
plt.bar(states,counts)    #Matplotlib
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(x=states,y=counts)           #seaborn
plt.title('This is my first Graph')
plt.xlabel('names of states')
plt.ylabel('counts')
plt.show()

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name = 'ERPData')

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df1 = df.MaterialID.value_counts()

# %%
df1
# Out:
# MaterialID
# TMI-43T    15
# AXCP-78    11
# DDBN-89     8
# SDRT-67     6
# GCVB-79     5
# LXCV-21     5
# Name: count, dtype: int64

# %%
plt.bar(df1.index,df1,color='purple')
# Out:
# <BarContainer object of 6 artists>

# %%
df2 = df.Location.value_counts()

# %%
df2
# Out:
# Location
# MWH-4    15
# MWH-1    11
# MWH-5    11
# MWH-2     9
# MWH-3     4
# Name: count, dtype: int64

# %%
plt.bar(df2.index,df2)
# Out:
# <BarContainer object of 5 artists>

# %%
grp1 = df.groupby('MaterialID')

# %%
grp1

# %%
df2=grp1.Quantity.agg('sum')

# %%
plt.bar(df2.index,df2)
# Out:
# <BarContainer object of 6 artists>

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df1 =pd.crosstab(df.Location, df.MaterialID)

# %%
df1
# Out:
# MaterialID  AXCP-78  DDBN-89  GCVB-79  LXCV-21  SDRT-67  TMI-43T
# Location
# MWH-1             5        3        0        0        2        1
# MWH-2             1        1        4        1        1        1
# MWH-3             1        1        0        1        0        1
# MWH-4             1        2        0        0        1       11
# MWH-5             3        1        1        3        2        1

# %%
plt.plot(df1.index,df1)

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name = 'nominal')

# %%
df.head()
# Out:
#    ses  write  math  prog
# 0    1     35    41     1
# 1    2     33    41     2
# 2    3     39    44     3
# 3    1     37    42     1
# 4    2     31    40     2

# %%
df1 = pd.crosstab(df.ses,df.prog)

# %%
df1
# Out:
# prog   1   2   3
# ses
# 1     29  16   2
# 2      6  51  38
# 3      1   9  48

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='ses'>

# %%
df = pd.read_excel('CDAC_DataBook.xlsx', sheet_name = 'ERPData')

# %%
plt.boxplot(df.Quantity)              # only we have continus data make boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ded79c71670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ded79c71040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ded79c71850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ded79c708c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ded79c705c0>],
#  'means': []}

# %%
male_sal = [4,6,5,3,7,6,8]
female_sal = [11,15,13,19,15]

# %%
plt.boxplot([male_sal,female_sal])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ded79c1b620>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ded79c1bb90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ded79c1b230>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ded79b542c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ded79e5fbf0>,
# ...
#  'means': []}

# %%
df = pd.read_excel('/content/data2.xlsx')
df.head()
# Out:
#   Category  Continuous_Value
# 0        C      -4008.098297
# 1        D      -3887.888132
# 2      NaN      -3712.188312
# 3        C      -3416.823821
# 4        D      -5845.073897

# %%
df[['Continuous_Value']].boxplot()
# Out:
# <Axes: >
